# %%
import requests
import pandas as pd
import json
from datetime import datetime
import os
import re

# %%
url = 'https://sv.shopee.co.id/api/v2/timeline/friends?limit=20&device_id=V9Qll8LdhYlN1LZkz%2FJ2hHe0z5lxNSO1AGwr08aQUEM%3D&is_preload=true&launch_type=1&os_type=2&system_version=24&sdk_version=1.51.3&model=Xiaomi%20Redmi%20Note%209&android_performance=187'

# %%
params = {
    "limit": "2",
    "device_id": f"V9Qll8LdhYlN1LZkz%2FJ2hHe0z5lxNSO1AGwr08aQUEM%3D",
    "is_preload": "true",
    "launch_type": "1",
    "os_type": "2",
    "system_version": "24",
    "sdk_version": "1.51.3",
    "model": "Xiaomi Redmi Note 9",
    "android_performance": "187"
}

# %%
headers = {
    "sv-from-source": "hot_start",
    "fid": "70cf227bc16d8581_unknown",
    "client-info": f"device_id=V9Qll8LdhYlN1LZkz%2FJ2hHe0z5lxNSO1AGwr08aQUEM%3D;device_model=Redmi+Note+9;os=0;os_version=24;client_version=32709;network=1;platform=1;rn_version=6.18.5;api_source=na",
    "language": "id",
    "referer": "HomeActivity_",
    "sfid": "oMSrG6guhvM6fNyrCA/i+g==|hwpx6JLEKdXrvc1RG0ZO9gUh8hsqZkxgalz8E5cYxWJWIl3svJY6HzfL6cjrQIGSOn+s1iNFODn9ucT3Lp+CNyAyalqOYA==|D8OBONonAxaSSzZ6|08|1",
    "x-shopee-client-timezone": "America/New_York",
    "client-request-id": "50665c8e-ba28-4648-8ddc-2db370aa2ccc.64",
    "accept-encoding": "gzip",
    "cookie": "userid=0; shopid=0; username=null; shopee_token=null; language=id; shopee_app_version=32709; SPC_CLIENTID=V9Qll8LdhYlN1LZkrqxizahpvpgymvxd; SPC_AFTID=3a4e0ba3-45e8-460a-b8a2-683483102b66; shopee_rn_version=1716550498; SPC_F=70cf227bc16d8581_unknown; UA=Shopee%20Android%20Beeshop%20locale%2Fid%20version%3D32709%20appver%3D32709; csrftoken=fCrq9SiLh7V1KtOkbFOBzWCiy9HsHkLl",
    "if-modified-since": "Thu, 06 Jun 2024 06:02:30 GMT",
    "user-agent": "okhttp/3.12.4 app_type=1",
    "af-ac-enc-dat": "...",
    "af-ac-enc-id": "Kpba7CQmXJsRBLAn+9ChcSFdpVG2zV/SrE7pXn8irJCHH4ftsfup1u6gN7ca9wG2V3DMaA==",
    "af-ac-enc-sz-token": "1DXQRnDvg8OySMqCMjSevA==|gApx6JLEKdXrvc1RG0ZO9gUh8hsqZkxgalz8E81KY+xJIl3svJT2VTsJursMJs2ryN0LOw9FODn9ucT3Lp+CNSAyalqOYA==|D8OBONonAxaSSzZ6|08|1",
    "d8feda18": "...",
    "x-sap-ri": "aa9f7f66e898ae26cf96ec120131a210d3a5d4274c8190a2cdb8",
    "13ceb317": "ZyhfYGxxFGCMeWi346Y+rLTToXj=",
    "54e87ab6": "ZX1FdLpzoT8pfNGnXcp4ty34r8j="
}

# %%
headers = {
    'accept': 'application/json, text/plain, */*',
    'language': 'id',
    'did': 'V9Qll8LdhYlN1LZkz/J2hHe0z5lxNSO1AGwr08aQUEM=',
    'fid': '70cf227bc16d8581_unknown',
    'x-requested-from': 'rn',
    'os-type': '2',
    'os-system-version': '24',
    'model': 'Xiaomi Redmi Note 9',
    'sdk-version': '1.51.3',
    'android-performance': '187',
    'referer': 'trending_page',
    'sv-from-source': 'video_tab',
    'sv-req-timestamp': '1717653798193',
    'sv-source-page': '',
    'sv-pre-page': '',
    'requestinfo': str({"deviceInfo":{"brand":"unknown","appDeviceName":"Brand/xiaomi Model/redmi_note_9 OSVer/24 Manufacturer/unknown","model":"Redmi Note 9","appOSVersion":"24","platform":0},"networkInfo":{"networkType":"wifi"},"locationInfo":{"addresses":[],"gps":{}}}),
    'requestinfo-enc': str("%7B%22deviceInfo%22%3A%7B%22brand%22%3A%22unknown%22%2C%22appDeviceName%22%3A%22Brand%2Fxiaomi%20Model%2Fredmi_note_9%20OSVer%2F24%20Manufacturer%2Funknown%22%2C%22model%22%3A%22Redmi%20Note%209%22%2C%22appOSVersion%22%3A%2224%22%2C%22platform%22%3A0%7D%2C%22networkInfo%22%3A%7B%22networkType%22%3A%22wifi%22%7D%2C%22locationInfo%22%3A%7B%22addresses%22%3A%5B%5D%2C%22gps%22%3A%7B%7D%7D%7D"),
    'x-request-id': '000003eb1a32707d0f3f000000000000:0000000000000000:0000000000000000',
    'sfid': 'oMSrG6guhvM6fNyrCA/i+g==|hwpx6JLEKdXrvc1RG0ZO9gUh8hsqZkxgalz8E5cYxWJWIl3svJY6HzfL6cjrQIGSOn+s1iNFODn9ucT3Lp+CNyAyalqOYA==|D8OBONonAxaSSzZ6|08|1',
    'x-shopee-client-timezone': 'America/New_York',
    'client-request-id': 'b8178bcf-f1fc-4002-b66d-0f267a96b65a.84',
    'content-type': 'application/json',
    'content-length':"301",
    'cookie': 'userid=0; shopid=0; username=null; shopee_token=null; language=id; shopee_app_version=32709; SPC_CLIENTID=V9Qll8LdhYlN1LZkrqxizahpvpgymvxd; SPC_AFTID=3a4e0ba3-45e8-460a-b8a2-683483102b66; shopee_rn_version=1716550498; SPC_F=70cf227bc16d8581_unknown; UA=Shopee%20Android%20Beeshop%20locale%2Fid%20version%3D32709%20appver%3D32709; csrftoken=AEHfdDy045zRtaceVH8O8Ckp8WB0xzyL',
    'user-agent': 'okhttp/3.12.4 app_type=1',
    'af-ac-enc-dat': '...',
    'af-ac-enc-id': '6FPmlQA2iPLrm+OqxxY8Wp2YBwVqEgR0b27U7A4pv6fADjaTecRCHFyCoKH/YuGmUFLYTA==',
    'af-ac-enc-sz-token': 'oMSrG6guhvM6fNyrCA/i+g==|hwpx6JLEKdXrvc1RG0ZO9gUh8hsqZkxgalz8E5cYxWJWIl3svJY6HzfL6cjrQIGSOn+s1iNFODn9ucT3Lp+CNyAyalqOYA==|D8OBONonAxaSSzZ6|08|1',
    'b5996a06': '...',
    '4619323a':'jr1iMyKAdoVZrfGE2b1tPNJ5uFy=',
    'x-sap-ri': '2651616665df263d58cbdb190169bd1944b024813dde727e0242',
    '23bc3170': 'gi0yilroNEGWfZX80tyxcjzyNyt=',
    '4715a708': 'LTf6oiR52A2gYzhJ73l7fOgv5YT=',
    'x-csrftoken': 'AEHfdDy045zRtaceVH8O8Ckp8WB0xzyL',
}

# %%
# Definisikan payload data yang akan dikirim dalam bentuk JSON
payload = {
    "limit": 6,
    "page_context": None,
    "device_id": "V9Qll8LdhYlN1LZkz/J2hHe0z5lxNSO1AGwr08aQUEM=",
    "rec_request_info": {
        "dayPages": 2,
        "sessionPages": 2,
        "interactDataFromVideo": [],
        "interactDataFromCard": [],
        "sessionCards": 0
    },
    "request_type": 0,
    "ext_info": [
        {"key": "ads_entrance", "value": "29"}
    ],
    "lang": "id"
}

# %%
# Mengubah payload menjadi JSON
#json_payload = json.dumps(payload)

# Mengirim permintaan POST dengan menggunakan requests
#response = requests.post(url, headers=headers, data=json_payload)

response = requests.get(url, headers=headers)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'code': 0, 'msg': 'Success', 'data': {'list': [{'allow_info': {'allow_duet': False, 'allow_stitch': False}, 'comments': [], 'content': {'caption': 'Binder keuangan #spillracunshopee #shopeehaul #shopeereview #binder #binderkeuangan #dompetkeuangan', 'hashtags': [{'hashtag_id': '12983052894340359843', 'is_official': True, 'length': 17, 'start': 16}, {'hashtag_id': '13906788008909034362', 'is_official': False, 'length': 11, 'start': 34}, {'hashtag_id': '9459618894215711701', 'is_official': False, 'length': 13, 'start': 46}, {'hashtag_id': '6549151054792090494', 'is_official': False, 'length': 7, 'start': 60}, {'hashtag_id': '8260940905213489574', 'is_official': False, 'length': 15, 'start': 68}, {'hashtag_id': '13939394971115440014', 'is_official': False, 'length': 15, 'start': 84}], 'incentive_info': {}, 'media_sdk_info': {'edit': [{}], 'template_id': 0}, 'mentions': [], 'music': {'author_name': 'Amalia Nurhasanah', 'cover': 'https://cf.shopee.co.id/file/id-11134233-7qul0-lk7ns8adjkg358', 'downloadable': True, 'duration': 16393, 'music_id': '2878692667150041426', 'start': 0, 'state': 0, 'title': '', 'type': 3, 'url': 'https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/2878692667150041426.10005921715834539.aac'}, 'products': {'anchor_product': {'attribution_tracking_data': '{"af_click_lookback":"7d","af_reengagement_window":"7d","af_siteid":"an_11395360359","af_sub_siteid":"----","af_viewthrough_lookback":"1d","c":"-","is_retargeting":"true","item_id":"20370337509","pid":"affiliates","shop_id":"850017754","utm_campaign":"-","utm_content":"ShopeeVideo","utm_medium":"affiliates","utm_source":"an_11395360359"}', 'custom_name': '', 'exclusive_path_token': 'AQAuEVlWiXAbQrbFwKEMO/gKbIOvfRnh/GJHnWacs4MusaPlf4SzlqvibfHu0jEU', 'from_source': 3, 'image': 'sg-11134201-23010-5dvbzlk53xmvab_tn', 'item_id': 20370337509, 'item_id_from': 0, 'name': 'Isi binder A6 saving challenge Tebal 260 gsm (KERTAS SAJA) / kertas menabung A6 / loose leaf', 'offer_link': 'https://shope.ee/7UuUec27XR', 'price': 99900000, 'price_before_discount': 0, 'scene': 1, 'shop_id': 850017754, 'source_comment_id': 0}, 'anchor_voucher': {'coin_cashback_info': {'cap': 0, 'percentage': 0}, 'discount_info': {'cap': 0, 'percentage': 0, 'value': 0}, 'from_source': 1, 'fsv_info': {'shipping_promotion_order_limit': 3, 'shipping_promotion_rules': [208246745075712, 208246753464320, 208296623738880, 208296644706604, 208296632127488, 208297307406336, 208296640516096, 208297315799040, 193346689827416, 193349185441792, 193346547224576, 193349126721536, 193346551414784, 193349130911744, 193346555609088, 193349135106048, 193346559807488, 193346563997996, 193346605944832, 193346576584704, 193346580774912, 193346584973312, 193346589163520, 193346601750528, 193346593357824, 193346597556224]}, 'identifier': {'promotion_id': 918436385488896, 'signature': '1f5d923cec16ac44b33e1edf3fb8b9d45c65ffe852f745f90890da0bbdc6a5e9', 'voucher_code': 'FSV-421701784965218304'}, 'min_spend': 0, 'product_rule': {'has_product_limit': False, 'product_scope': {'exclusive_channel_type': 2}}, 'reward_type': 2, 'shop_id': 0, 'shop_item_ids': [{'item_id': 20370337509, 'shop_id': 850017754}, {'item_id': 22172140315, 'shop_id': 958728726}, {'item_id': 22480824734, 'shop_id': 958728726}], 'time_info': {'end_time': 1719766740, 'start_time': 1719162000}, 'ui_info': {'title': ''}, 'user_claimed': False, 'voucher_class': 1}, 'count': 3, 'item_list': [{'ads_info': {'ads_type': 0}, 'item_id': 20370337509, 'mcn_campaign_token': '', 'shop_id': 850017754}, {'ads_info': {'ads_type': 0}, 'item_id': 22172140315, 'mcn_campaign_token': '', 'shop_id': 958728726}, {'ads_info': {'ads_type': 0}, 'item_id': 22480824734, 'mcn_campaign_token': '', 'shop_id': 958728726}], 'items': [{'image': 'sg-11134201-23010-5dvbzlk53xmvab_tn'}, {'image': 'id-11134207-7r991-lwpfenutsyemd5_tn'}, {'image': 'id-11134207-7r990-lmo7zcq1y13za5_tn'}]}, 'video': {'cover': 'https://down-ws-id.img.susercontent.com/id-11110124-7r990-lvcrdumd17a860', 'dura ...

# %%
formatted_response = json.dumps(response.json(), indent=4)

print(formatted_response)
# Out:
# {
#     "code": 0,
#     "msg": "Success",
#     "data": {
#         "list": [
#             {
#                 "allow_info": {
#                     "allow_duet": false,
#                     "allow_stitch": false
#                 },
#                 "comments": [],
#                 "content": {
#                     "caption": "Binder keuangan #spillracunshopee #shopeehaul #shopeereview #binder #binderkeuangan #dompetkeuangan",
#                     "hashtags": [
#                         {
#                             "hashtag_id": "12983052894340359843",
#                             "is_official": true,
#                             "length": 17,
#                             "start": 16
#                         },
#                         {
#                             "hashtag_id": "13906788008909034362",
#                             "is_official": false,
#                             "length": 11,
#                             "start": 34
#                         },
#                         {
#                             "hashtag_id": "9459618894215711701",
#                             "is_official": false,
#                             "length": 13,
#                             "start": 46
#                         },
#                         {
#                             "hashtag_id": "6549151054792090494",
#                             "is_official": false,
#                             "length": 7,
#                             "start": 60
#                         },
#                         {
#                             "hashtag_id": "8260940905213489574",
#                             "is_official": false,
#                             "length": 15,
#                             "start": 68
#                         },
#                         {
#                             "hashtag_id": "13939394971115440014",
#                             "is_official": false,
#                             "length": 15,
#                             "start": 84
#                         }
#                     ],
#                     "incentive_info": {},
#                     "media_sdk_info": {
#                         "edit": [
#                             {}
#                         ],
#                         "template_id": 0
#                     },
#                     "mentions": [],
#                     "music": {
#                         "author_name": "Amalia Nurhasanah",
#                         "cover": "https://cf.shopee.co.id/file/id-11134233-7qul0-lk7ns8adjkg358",
#                         "downloadable": true,
#                         "duration": 16393,
#                         "music_id": "2878692667150041426",
#                         "start": 0,
#                         "state": 0,
#                         "title": "",
#                         "type": 3,
#                         "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/2878692667150041426.10005921715834539.aac"
#                     },
#                     "products": {
#                         "anchor_product": {
#                             "attribution_tracking_data": "{\"af_click_lookback\":\"7d\",\"af_reengagement_window\":\"7d\",\"af_siteid\":\"an_11395360359\",\"af_sub_siteid\":\"----\",\"af_viewthrough_lookback\":\"1d\",\"c\":\"-\",\"is_retargeting\":\"true\",\"item_id\":\"20370337509\",\"pid\":\"affiliates\",\"shop_id\":\"850017754\",\"utm_campaign\":\"-\",\"utm_content\":\"ShopeeVideo\",\"utm_medium\":\"affiliates\",\"utm_source\":\"an_11395360359\"}",
#                             "custom_name": "",
#                             "exclusive_path_token": "AQAuEVlWiXAbQrbFwKEMO/gKbIOvfRnh/GJHnWacs4MusaPlf4SzlqvibfHu0jEU",
#                             "from_source": 3,
#                             "image": "sg-11134201-23010-5dvbzlk53xmvab_tn",
#                             "item_id": 20370337509,
#                             "item_id_from": 0,
#                             "name": "Isi binder A6 saving challenge Tebal 260 gsm (KERTAS SAJA) / kertas menabung A6 / loose leaf",
#                             "offer_link": "https://shope.ee/7UuUec27XR",
#                             "price": 99900000,
#                             "price_before_discount": 0,
#                             "scene": 1,
#                             "shop_id": 850017754,
#                             "source_comment_id": 0
#                         },
#                         "anchor_voucher": {
#                             "coin_cashback_info": {
#                                 "cap": 0,
#                                 "percentage": 0
#                             },
#                             "discount_info": {
#                                 "cap": 0,
#                                 "percentage": 0,
#                                 "value": 0
#                             },
#                             "from_source": 1,
#                             "fsv_info": {
#                                 "shipping_promotion_order_limit": 3,
#                                 "shipping_promotion_rules": [
#                                     208246745075712,
#                                     208246753464320,
#                                     208296623738880,
#                                     208296644706604,
#                                     208296632127488,
#                                     208297307406336,
#                                     208296640516096,
#                                     208297315799040,
#                                     193346689827416,
#                                     193349185441792,
#                                     193346547224576,
#                                     193349126721536,
#                                     193346551414784,
#                                     193349130911744,
#                                     193346555609088,
#                                     193349135106048,
#                                     193346559807488,
#                                     193346563997996,
#                                     193346605944832,
#                                     193346576584704,
#                                     193346580774912,
#                                     193346584973312,
#                                     193346589163520,
#                                     193346601750528,
#                                     193346593357824,
#                                     193346597556224
#                                 ]
#                             },
#                             "identifier": {
#                                 "promotion_id": 918436385488896,
#                                 "signature": "1f5d923cec16ac44b33e1edf3fb8b9d45c65ffe852f745f90890da0bbdc6a5e9",
#                                 "voucher_code": "FSV-421701784965218304"
#                             },
#                             "min_spend": 0,
#                             "product_rule": {
#                                 "has_product_limit": false,
#                                 "product_scope": {
#                                     "exclusive_channel_type": 2
#                                 }
#                             },
#                             "reward_type": 2,
#                             "shop_id": 0,
#                             "shop_item_ids": [
#                                 {
#                                     "item_id": 20370337509,
#                                     "shop_id": 850017754
#                                 },
#                                 {
#                                     "item_id": 22172140315,
#                                     "shop_id": 958728726
#                                 },
#                                 {
#                                     "item_id": 22480824734,
#                                     "shop_id": 958728726
#                                 }
#                             ],
#                             "time_info": {
#                                 "end_time": 1719766740,
#                                 "start_time": 1719162000
#                             },
#                             "ui_info": {
#                                 "title": ""
#                             },
#                             "user_claimed": false,
#                             "voucher_class": 1
#                         },
#                         "count": 3,
#                         "item_list": [
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 20370337509,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 850017754
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 22172140315,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 958728726
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 22480824734,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 958728726
#                             }
#                         ],
#                         "items": [
#                             {
#                                 "image": "sg-11134201-23010-5dvbzlk53xmvab_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r991-lwpfenutsyemd5_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r990-lmo7zcq1y13za5_tn"
#                             }
#                         ]
#                     },
#                     "video": {
#                         "cover": "https://down-ws-id.img.susercontent.com/id-11110124-7r990-lvcrdumd17a860",
#                         "duration": 16366,
#                         "formats": [
#                             {
#                                 "bitrate": 350725,
#                                 "defn": "V360P",
#                                 "duration": 16371,
#                                 "format": 1600408,
#                                 "height": 640,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004081716229997.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004081716229997.mp4",
#                                 "width": 360
#                             },
#                             {
#                                 "bitrate": 657090,
#                                 "defn": "V540P",
#                                 "duration": 16371,
#                                 "format": 1600409,
#                                 "height": 960,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004091716229977.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004091716229977.mp4",
#                                 "width": 540
#                             },
#                             {
#                                 "bitrate": 1069510,
#                                 "defn": "V720P",
#                                 "duration": 16371,
#                                 "format": 1600410,
#                                 "height": 1280,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004101716229997.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004101716229997.mp4",
#                                 "width": 720
#                             }
#                         ],
#                         "height": 1280,
#                         "mms_cover": "https://down-ws-id.img.susercontent.com/id-11110124-7r990-lvcrdumd17a860",
#                         "mms_data": "{\"biz\":125,\"cover\":\"https://down-ws-id.img.susercontent.com/id-11110124-7r990-lvcrdumd17a860\",\"create_time\":1715834537,\"default_format\":{\"abitrate\":125520,\"bitrate\":456989,\"defn\":\"V540P\",\"duration\":16384,\"format\":1600323,\"fps\":25.06127,\"height\":960,\"profile\":\"MP4\",\"size\":1203190,\"update_time\":1715834558,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.default.mp4\",\"width\":540},\"duration\":16366,\"extend_formats\":{\"H265\":[{\"abitrate\":96526,\"bitrate\":385533,\"defn\":\"V360P\",\"duration\":16371,\"format\":1600412,\"fps\":25.06127,\"height\":640,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004121716229997.mp4\",\"profile\":\"MP4\",\"size\":1001976,\"update_time\":1716230020,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004121716229997.mp4\",\"width\":360},{\"abitrate\":125553,\"bitrate\":718418,\"defn\":\"V540P\",\"duration\":16371,\"format\":1600413,\"fps\":25.06127,\"height\":960,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004131716229997.mp4\",\"profile\":\"MP4\",\"size\":1740434,\"update_time\":1716230024,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004131716229997.mp4\",\"width\":540},{\"abitrate\":125553,\"bitrate\":1137301,\"defn\":\"V720P\",\"duration\":16371,\"format\":1600414,\"fps\":25.06127,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004141716229997.mp4\",\"profile\":\"MP4\",\"size\":2594986,\"update_time\":1716230034,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004141716229997.mp4\",\"width\":720},{\"abitrate\":125553,\"bitrate\":1137301,\"defn\":\"V720P\",\"duration\":16371,\"format\":1600415,\"fps\":25.06127,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004151716229997.mp4\",\"profile\":\"MP4\",\"size\":2594987,\"update_time\":1716230033,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004151716229997.mp4\",\"width\":720}]},\"formats\":[{\"abitrate\":96526,\"bitrate\":350725,\"defn\":\"V360P\",\"duration\":16371,\"format\":1600408,\"fps\":25.06127,\"height\":640,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004081716229997.mp4\",\"profile\":\"MP4\",\"size\":928100,\"update_time\":1716230015,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004081716229997.mp4\",\"width\":360},{\"abitrate\":125553,\"bitrate\":657090,\"defn\":\"V540P\",\"duration\":16371,\"format\":1600409,\"fps\":25.06127,\"height\":960,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004091716229977.mp4\",\"profile\":\"MP4\",\"size\":1612469,\"update_time\":1716229996,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004091716229977.mp4\",\"width\":540},{\"abitrate\":125553,\"bitrate\":1069510,\"defn\":\"V720P\",\"duration\":16371,\"format\":1600410,\"fps\":25.06127,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004101716229997.mp4\",\"profile\":\"MP4\",\"size\":2453805,\"update_time\":1716230018,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004101716229997.mp4\",\"width\":720},{\"abitrate\":125553,\"bitrate\":1165141,\"defn\":\"V720P\",\"duration\":16371,\"format\":1600411,\"fps\":25.06127,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004111716229997.mp4\",\"profile\":\"MP4\",\"size\":2648893,\"update_time\":1716230021,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004111716229997.mp4\",\"width\":720}],\"serviceID\":6,\"update_time ...
#                         "preload_mms_data": "",
#                         "preload_url": "",
#                         "size": 24253,
#                         "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16004101716229997.mp4",
#                         "video_id": "id-11110124-6ke18-lvcr4hs211j9a3",
#                         "watermark_cover_url": "id-11134114-7r992-lvcrdtso8atl1a",
#                         "watermark_video_url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke18-lvcr4hs211j9a3.16003551715834539.5645.mp4",
#                         "width": 720
#                     }
#                 },
#                 "extend": {
#                     "bought": false
#                 },
#                 "in_fmt_wl": false,
#                 "interact": {},
#                 "label": {},
#                 "meta": {
#                     "avatar": "id-11134233-7r98q-lvfvg7r43vdrab",
#                     "content_type": 0,
#                     "count_info": {
#                         "comments": 13,
#                         "likes": 652,
#                         "views": 112560
#                     },
#                     "ctime": 1715834537552,
#                     "human_like": true,
#                     "is_verified": false,
#                     "post_id": "eEF8nz69BQCAr1owAAAAAA==",
#                     "qc_info": {
#                         "qc_time": 1717071093876,
#                         "violation_category": 0
#                     },
#                     "qc_status": 1,
#                     "shopee_nick_name": "Amalia Nurhasanah",
#                     "source": 0,
#                     "status": 1,
#                     "user_id": 811249536,
#                     "user_name": "amelnhasanah",
#                     "user_state": 0
#                 },
#                 "recommend_info": {
#                     "algo_info": "RCLG:default,REQID:011719641902894360010211206146026850449,PID:11,EPT:video_trending,TFS:rootsvr_ID,ABTEST:0.z.8888@63961,SEC:video_trending_sec,SECKEY:video_trending_sec,BNDOPT:video_trending,BND:video_trending,RNKG:default,NEW:1,SLT:rootsvr,LOWVVUSER:1,USERGROUP:noage_nogender,USERID:2063807778,DEVICE_FGPT_USERID:2063807778,UIDZERO:1,IS_NEW_USER:0,HISTORYLOWVVUSER:0,COINUSER:0,COREUSER:0,REQTYPE:1,UNIRANK:0,REQCNT:14,VVCNT:20,POS:0,QUE:ShopeeVideo_staytime_dssm_inbatch,QUES:ShopeeVideo_staytime_dssm_inbatch|ShopeeVideo_finish_dssm|ShopeeVideo_ecom_weighted_clk,GID:212858026,VIDEOID:1615451544895864,ITEMID:20370337509,SHOPID:850017754,BIND_PRODUCT_SIZE:3,AUTHORID:811249536,SIMID:1615451544895864,RNK:VideoGeneralRanker:{SCORE:94444344589149903310616002560.000000},CORECONTENT:0,TAG_INFO:tag_list:merchandise_video,not_video_cold_phase_one,ecom_video1,not_core_context,original_author,;tag_map:l1_cate_stats_tag:Culture & Education,;duration:15_20s,;l1_cat_shuffle_except_beauty:14,;l1_cat_shuffle:14,;freshness_stats_tag:30_60d,;is_ecom_stats_tag:ecom,;uid_shuffle:811249536,;source_stats_tag:UGC,;first_productid_shuffle:20370337509,;,RRK:original_author_boost_rule=755554756713199205092829790470144.000000&cold_start_ucb_boost_td_v2=755554756713199205092829790470144.000000&new_low_quality_traffic_baiting_deboost_for_td_hpl_ddl=755554756713199205092829790470144.000000&duration_stage_boost=755554756713199205092829790470144.000000",
#                     "ecommerce_source": {
#                         "item_id": 0,
#                         "tag": ""
#                     },
#                     "req_id": "011719641902894360010211206146026850449",
#                     "session_id": "",
#                     "source": 0,
#                     "video_type": 0
#                 },
#                 "relation_source": 0
#             },
#             {
#                 "allow_info": {
#                     "allow_duet": true,
#                     "allow_stitch": true
#                 },
#                 "comments": [],
#                 "content": {
#                     "caption": "Latiao snack #latiao #latiaoviral #fyp #RacunShopee #SpillRacunShopee",
#                     "hashtags": [
#                         {
#                             "hashtag_id": "17109635208311487009",
#                             "is_official": false,
#                             "length": 7,
#                             "start": 13
#                         },
#                         {
#                             "hashtag_id": "16778228841275556171",
#                             "is_official": false,
#                             "length": 12,
#                             "start": 21
#                         },
#                         {
#                             "hashtag_id": "7871083262959930263",
#                             "is_official": false,
#                             "length": 4,
#                             "start": 34
#                         },
#                         {
#                             "hashtag_id": "9502339962027776655",
#                             "is_official": true,
#                             "length": 12,
#                             "start": 39
#                         },
#                         {
#                             "hashtag_id": "12983052894340359843",
#                             "is_official": true,
#                             "length": 17,
#                             "start": 52
#                         }
#                     ],
#                     "incentive_info": {},
#                     "media_sdk_info": {
#                         "edit": [
#                             {}
#                         ],
#                         "template_id": 0
#                     },
#                     "mentions": [],
#                     "music": {
#                         "author_name": "indrianidewiavianti",
#                         "cover": "id-11134233-7r98y-lqqddb6ufyin3f@resize_bs320x320!",
#                         "downloadable": true,
#                         "duration": 24543,
#                         "music_id": "2881349193123758409",
#                         "start": 0,
#                         "state": 0,
#                         "title": "",
#                         "type": 3,
#                         "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/2881349193123758409.10005921717417952.aac"
#                     },
#                     "products": {
#                         "anchor_product": {
#                             "attribution_tracking_data": "{\"af_click_lookback\":\"7d\",\"af_reengagement_window\":\"7d\",\"af_siteid\":\"an_11351450195\",\"af_sub_siteid\":\"----\",\"af_viewthrough_lookback\":\"1d\",\"c\":\"-\",\"is_retargeting\":\"true\",\"item_id\":\"26401334000\",\"pid\":\"affiliates\",\"shop_id\":\"1081118682\",\"utm_campaign\":\"-\",\"utm_content\":\"ShopeeVideo\",\"utm_medium\":\"affiliates\",\"utm_source\":\"an_11351450195\"}",
#                             "custom_name": "",
#                             "exclusive_path_token": "AQBA3a5gQtYmasiBYB5K+PQsQ/VlGkhA3Ps8coDJPOXxFPI1WCNx1apjDbOmBQA=",
#                             "from_source": 3,
#                             "image": "id-11134207-7r98r-lws04tfghli69e_tn",
#                             "item_id": 26401334000,
#                             "item_id_from": 0,
#                             "name": "Latiao Family Snack - [HALAL] WLM Gluten Latiao Snack a Vegetarian Food",
#                             "offer_link": "https://s.shopee.co.id/owx9XCTk",
#                             "price": 1090000000,
#                             "price_before_discount": 4000000000,
#                             "scene": 1,
#                             "shop_id": 1081118682,
#                             "source_comment_id": 0
#                         },
#                         "anchor_voucher": {
#                             "coin_cashback_info": {
#                                 "cap": 0,
#                                 "percentage": 0
#                             },
#                             "discount_info": {
#                                 "cap": 0,
#                                 "percentage": 0,
#                                 "value": 0
#                             },
#                             "from_source": 1,
#                             "fsv_info": {
#                                 "shipping_promotion_order_limit": 3,
#                                 "shipping_promotion_rules": [
#                                     208246745075712,
#                                     208246753464320,
#                                     208296623738880,
#                                     208296644706604,
#                                     208296632127488,
#                                     208297307406336,
#                                     208296640516096,
#                                     208297315799040,
#                                     193346689827416,
#                                     193349185441792,
#                                     193346547224576,
#                                     193349126721536,
#                                     193346551414784,
#                                     193349130911744,
#                                     193346555609088,
#                                     193349135106048,
#                                     193346559807488,
#                                     193346563997996,
#                                     193346605944832,
#                                     193346576584704,
#                                     193346580774912,
#                                     193346584973312,
#                                     193346589163520,
#                                     193346601750528,
#                                     193346593357824,
#                                     193346597556224
#                                 ]
#                             },
#                             "identifier": {
#                                 "promotion_id": 918436385488896,
#                                 "signature": "1f5d923cec16ac44b33e1edf3fb8b9d45c65ffe852f745f90890da0bbdc6a5e9",
#                                 "voucher_code": "FSV-421701784965218304"
#                             },
#                             "min_spend": 0,
#                             "product_rule": {
#                                 "has_product_limit": false,
#                                 "product_scope": {
#                                     "exclusive_channel_type": 2
#                                 }
#                             },
#                             "reward_type": 2,
#                             "shop_id": 0,
#                             "shop_item_ids": [
#                                 {
#                                     "item_id": 26401334000,
#                                     "shop_id": 1081118682
#                                 },
#                                 {
#                                     "item_id": 23362106341,
#                                     "shop_id": 221423324
#                                 },
#                                 {
#                                     "item_id": 14198890656,
#                                     "shop_id": 994382543
#                                 },
#                                 {
#                                     "item_id": 22144486442,
#                                     "shop_id": 1001432919
#                                 }
#                             ],
#                             "time_info": {
#                                 "end_time": 1719766740,
#                                 "start_time": 1719162000
#                             },
#                             "ui_info": {
#                                 "title": ""
#                             },
#                             "user_claimed": false,
#                             "voucher_class": 1
#                         },
#                         "count": 4,
#                         "item_list": [
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 26401334000,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 1081118682
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 25366435929,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 981710403
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 19996355515,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 981710403
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 23362106341,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 221423324
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 14198890656,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 994382543
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 22144486442,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 1001432919
#                             }
#                         ],
#                         "items": [
#                             {
#                                 "image": "id-11134207-7r98r-lws04tfghli69e_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98r-loumsg5vppon0b_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98o-ll1xqxa6r20fdd_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98x-lwlay5op75otcb_tn"
#                             }
#                         ]
#                     },
#                     "qc_labels": [
#                         {
#                             "type": 6
#                         }
#                     ],
#                     "video": {
#                         "cover": "https://down-ws-id.img.susercontent.com/id-11110124-7r98o-lw2vku3uhcj072",
#                         "duration": 24520,
#                         "formats": [
#                             {
#                                 "bitrate": 266495,
#                                 "defn": "V360P",
#                                 "duration": 24520,
#                                 "format": 1600408,
#                                 "height": 640,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004081717508068.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004081717508068.mp4",
#                                 "width": 360
#                             },
#                             {
#                                 "bitrate": 502416,
#                                 "defn": "V540P",
#                                 "duration": 24520,
#                                 "format": 1600409,
#                                 "height": 960,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004091717508056.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004091717508056.mp4",
#                                 "width": 540
#                             },
#                             {
#                                 "bitrate": 628569,
#                                 "defn": "V720P",
#                                 "duration": 24520,
#                                 "format": 1600410,
#                                 "height": 1024,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004101717508068.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004101717508068.mp4",
#                                 "width": 576
#                             }
#                         ],
#                         "height": 1024,
#                         "mms_cover": "https://down-ws-id.img.susercontent.com/id-11110124-7r98o-lw2vku3uhcj072",
#                         "mms_data": "{\"biz\":125,\"cover\":\"https://down-ws-id.img.susercontent.com/id-11110124-7r98o-lw2vku3uhcj072\",\"create_time\":1717417883,\"default_format\":{\"abitrate\":128218,\"bitrate\":456600,\"defn\":\"V540P\",\"duration\":24534,\"format\":1600323,\"fps\":25.04085,\"height\":960,\"profile\":\"MP4\",\"size\":1810375,\"update_time\":1717417967,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.default.mp4\",\"width\":540},\"duration\":24520,\"extend_formats\":{\"H265\":[{\"abitrate\":96279,\"bitrate\":230682,\"defn\":\"V360P\",\"duration\":24520,\"format\":1600412,\"fps\":25.04085,\"height\":640,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004121717508068.mp4\",\"profile\":\"MP4\",\"size\":1025961,\"update_time\":1717508086,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004121717508068.mp4\",\"width\":360},{\"abitrate\":128261,\"bitrate\":398095,\"defn\":\"V540P\",\"duration\":24520,\"format\":1600413,\"fps\":25.04085,\"height\":960,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004131717508068.mp4\",\"profile\":\"MP4\",\"size\":1636262,\"update_time\":1717508097,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004131717508068.mp4\",\"width\":540},{\"abitrate\":128261,\"bitrate\":516411,\"defn\":\"V720P\",\"duration\":24520,\"format\":1600414,\"fps\":25.04085,\"height\":1024,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004141717508068.mp4\",\"profile\":\"MP4\",\"size\":1998313,\"update_time\":1717508100,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004141717508068.mp4\",\"width\":576},{\"abitrate\":128261,\"bitrate\":575336,\"defn\":\"V720P\",\"duration\":24520,\"format\":1600415,\"fps\":25.04085,\"height\":1024,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004151717508068.mp4\",\"profile\":\"MP4\",\"size\":2178626,\"update_time\":1717508101,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004151717508068.mp4\",\"width\":576}]},\"formats\":[{\"abitrate\":96279,\"bitrate\":266495,\"defn\":\"V360P\",\"duration\":24520,\"format\":1600408,\"fps\":25.04085,\"height\":640,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004081717508068.mp4\",\"profile\":\"MP4\",\"size\":1132420,\"update_time\":1717508076,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004081717508068.mp4\",\"width\":360},{\"abitrate\":128261,\"bitrate\":502416,\"defn\":\"V540P\",\"duration\":24520,\"format\":1600409,\"fps\":25.04085,\"height\":960,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004091717508056.mp4\",\"profile\":\"MP4\",\"size\":1952376,\"update_time\":1717508068,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004091717508056.mp4\",\"width\":540},{\"abitrate\":128261,\"bitrate\":628569,\"defn\":\"V720P\",\"duration\":24520,\"format\":1600410,\"fps\":25.04085,\"height\":1024,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004101717508068.mp4\",\"profile\":\"MP4\",\"size\":2338382,\"update_time\":1717508082,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004101717508068.mp4\",\"width\":576},{\"abitrate\":128261,\"bitrate\":990633,\"defn\":\"V720P\",\"duration\":24520,\"format\":1600411,\"fps\":25.04085,\"height\":1024,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004111717508068.mp4\",\"profile\":\"MP4\",\"size\":3446297,\"update_time\":1717508081,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004111717508068.mp4\",\"width\":576}],\"serviceID\":6,\"update_time\": ...
#                         "preload_mms_data": "",
#                         "preload_url": "",
#                         "size": 24879,
#                         "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16004101717508068.mp4",
#                         "video_id": "id-11110124-6ke1j-lw2vku3ufxyke1",
#                         "watermark_cover_url": "id-11134114-7r98o-lw2x1l41bl23c6",
#                         "watermark_video_url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1j-lw2vku3ufxyke1.16003551717417951.7856.mp4",
#                         "width": 576
#                     }
#                 },
#                 "extend": {
#                     "bought": false
#                 },
#                 "in_fmt_wl": false,
#                 "interact": {},
#                 "label": {},
#                 "meta": {
#                     "avatar": "id-11134233-7r98y-lqqddb6ufyin3f",
#                     "content_type": 0,
#                     "count_info": {
#                         "comments": 90,
#                         "likes": 4772,
#                         "views": 1031330
#                     },
#                     "ctime": 1717417950603,
#                     "human_like": true,
#                     "is_verified": false,
#                     "post_id": "w0dK3dbUBQA5IcYHAAAAAA==",
#                     "qc_info": {
#                         "qc_time": 1717493659509,
#                         "violation_category": 0
#                     },
#                     "qc_status": 1,
#                     "shopee_nick_name": "indrianidewiavianti",
#                     "source": 0,
#                     "status": 1,
#                     "user_id": 130425145,
#                     "user_name": "namakuindri_",
#                     "user_state": 0
#                 },
#                 "recommend_info": {
#                     "algo_info": "RCLG:default,REQID:011719641902894360010211206146026850449,PID:11,EPT:video_trending,TFS:rootsvr_ID,ABTEST:0.z.8888@63961,SEC:video_trending_sec,SECKEY:video_trending_sec,BNDOPT:video_trending,BND:video_trending,RNKG:default,NEW:1,SLT:rootsvr,LOWVVUSER:1,USERGROUP:noage_nogender,USERID:2063807778,DEVICE_FGPT_USERID:2063807778,UIDZERO:1,IS_NEW_USER:0,HISTORYLOWVVUSER:0,COINUSER:0,COREUSER:0,REQTYPE:1,UNIRANK:0,REQCNT:14,VVCNT:20,POS:1,QUE:ShopeeVideo_ecom_weighted_clk,QUES:ShopeeVideo_ecom_weighted_clk,GID:146989511,VIDEOID:1641394184275907,ITEMID:26401334000,SHOPID:1081118682,BIND_PRODUCT_SIZE:4,AUTHORID:130425145,SIMID:1467321196414678,RNK:VideoGeneralRanker:{SCORE:32488638796019234490443366400.000000},CORECONTENT:1,TAG_INFO:tag_list:product_related_shuffle,not_video_cold_phase_one,ecom_video1,merchandise_video,core_context,lang_l1_not_28_88,original_author,;tag_map:l1_cate_stats_tag:Food & Drink,;duration:20_30s,;l1_cat_shuffle_except_beauty:5,;l1_cat_shuffle:5,;freshness_stats_tag:14_30d,;is_ecom_stats_tag:ecom,;uid_shuffle:130425145,;source_stats_tag:UGC,;first_productid_shuffle:26401334000,;,RRK:original_author_boost_rule=259909110368153885212221162651648.000000&cold_start_ucb_boost_td_v2=259909110368153885212221162651648.000000&new_low_quality_traffic_baiting_deboost_for_td_hpl_ddl=259909110368153885212221162651648.000000&duration_stage_boost=259909110368153885212221162651648.000000",
#                     "ecommerce_source": {
#                         "item_id": 0,
#                         "tag": ""
#                     },
#                     "req_id": "011719641902894360010211206146026850449",
#                     "session_id": "",
#                     "source": 0,
#                     "video_type": 0
#                 },
#                 "relation_source": 0
#             },
#             {
#                 "allow_info": {
#                     "allow_duet": false,
#                     "allow_stitch": false
#                 },
#                 "comments": [],
#                 "content": {
#                     "caption": "Kolam renang portable #kolamrenangportable #Diskon40RB #GratisOngkirRP0 #RacunShopee #ViralDiShopeeVideo #SpillRacunShopee #kolamrenang #kolamrenangan",
#                     "hashtags": [
#                         {
#                             "hashtag_id": "7413916719644770875",
#                             "is_official": false,
#                             "length": 20,
#                             "start": 22
#                         },
#                         {
#                             "hashtag_id": "9586355226241151374",
#                             "is_official": true,
#                             "length": 11,
#                             "start": 43
#                         },
#                         {
#                             "hashtag_id": "4450219360474072404",
#                             "is_official": true,
#                             "length": 16,
#                             "start": 55
#                         },
#                         {
#                             "hashtag_id": "9502339962027776655",
#                             "is_official": true,
#                             "length": 12,
#                             "start": 72
#                         },
#                         {
#                             "hashtag_id": "14693555798190311673",
#                             "is_official": true,
#                             "length": 19,
#                             "start": 85
#                         },
#                         {
#                             "hashtag_id": "12983052894340359843",
#                             "is_official": true,
#                             "length": 17,
#                             "start": 105
#                         },
#                         {
#                             "hashtag_id": "9682624801042283080",
#                             "is_official": false,
#                             "length": 12,
#                             "start": 123
#                         },
#                         {
#                             "hashtag_id": "14093641557571046389",
#                             "is_official": false,
#                             "length": 14,
#                             "start": 136
#                         }
#                     ],
#                     "incentive_info": {},
#                     "media_sdk_info": {
#                         "edit": [
#                             {}
#                         ],
#                         "template_id": 0
#                     },
#                     "mentions": [],
#                     "music": {
#                         "author_name": "WILDA",
#                         "cover": "https://cf.shopee.co.id/file/id-11134233-7r98p-lqevsnq11ss8e7",
#                         "downloadable": true,
#                         "duration": 12515,
#                         "music_id": "2876958505351250305",
#                         "start": 0,
#                         "state": 0,
#                         "title": "",
#                         "type": 3,
#                         "url": "https://down-tx-id.vod.susercontent.com/api/v4/11110124/mms/2876958505351250305.10005921714800898.aac"
#                     },
#                     "products": {
#                         "anchor_product": {
#                             "attribution_tracking_data": "{\"af_click_lookback\":\"7d\",\"af_reengagement_window\":\"7d\",\"af_siteid\":\"an_11318850018\",\"af_sub_siteid\":\"----\",\"af_viewthrough_lookback\":\"1d\",\"c\":\"-\",\"is_retargeting\":\"true\",\"item_id\":\"18090028331\",\"pid\":\"affiliates\",\"shop_id\":\"494896079\",\"utm_campaign\":\"-\",\"utm_content\":\"ShopeeVideo\",\"utm_medium\":\"affiliates\",\"utm_source\":\"an_11318850018\"}",
#                             "custom_name": "",
#                             "exclusive_path_token": "AQD1MRCM1H2aNrFw5C4Sa53yHmYQGtnBdXagzXEh+s9AnItSpw7oh9BFT2i+KNA=",
#                             "from_source": 3,
#                             "image": "id-11134207-7qula-li89btvcxroqea_tn",
#                             "item_id": 18090028331,
#                             "item_id_from": 0,
#                             "name": "Satu Keluarga Mainan Anak Kolam Renang Karet M327 Kolam Renang Keluarga Ocean Dasar Gelembung / Swimming Pool\u00a0Baby\u00a0Bathtub",
#                             "offer_link": "https://shope.ee/B7aq40wzY",
#                             "price": 8203700000,
#                             "price_before_discount": 11400000000,
#                             "scene": 1,
#                             "shop_id": 494896079,
#                             "source_comment_id": 0
#                         },
#                         "anchor_voucher": {
#                             "coin_cashback_info": {
#                                 "cap": 0,
#                                 "percentage": 0
#                             },
#                             "discount_info": {
#                                 "cap": 0,
#                                 "percentage": 0,
#                                 "value": 0
#                             },
#                             "from_source": 1,
#                             "fsv_info": {
#                                 "shipping_promotion_order_limit": 3,
#                                 "shipping_promotion_rules": [
#                                     208246745075712,
#                                     208246753464320,
#                                     208296623738880,
#                                     208296644706604,
#                                     208296632127488,
#                                     208297307406336,
#                                     208296640516096,
#                                     208297315799040,
#                                     193346689827416,
#                                     193349185441792,
#                                     193346547224576,
#                                     193349126721536,
#                                     193346551414784,
#                                     193349130911744,
#                                     193346555609088,
#                                     193349135106048,
#                                     193346559807488,
#                                     193346563997996,
#                                     193346605944832,
#                                     193346576584704,
#                                     193346580774912,
#                                     193346584973312,
#                                     193346589163520,
#                                     193346601750528,
#                                     193346593357824,
# ...
#                             "product_rule": {
#                                 "has_product_limit": true,
#                                 "product_scope": {
#                                     "exclusive_channel_type": 2,
#                                     "stream_rule": {
#                                         "streamer_user_segment": "SV Orange Tick_test"
#                                     }
#                                 }
#                             },
#                             "reward_type": 0,
#                             "shop_id": 0,
#                             "shop_item_ids": [
#                                 {
#                                     "item_id": 20137254458,
#                                     "shop_id": 759343791
#                                 },
#                                 {
#                                     "item_id": 23751256425,
#                                     "shop_id": 260118109
#                                 },
#                                 {
#                                     "item_id": 19682971494,
#                                     "shop_id": 4627733
#                                 },
#                                 {
#                                     "item_id": 22751371383,
#                                     "shop_id": 330314777
#                                 },
#                                 {
#                                     "item_id": 22276845180,
#                                     "shop_id": 319151384
#                                 },
#                                 {
#                                     "item_id": 19582981087,
#                                     "shop_id": 759343791
#                                 }
#                             ],
#                             "time_info": {
#                                 "end_time": 1719680340,
#                                 "start_time": 1719594000
#                             },
#                             "ui_info": {
#                                 "title": ""
#                             },
#                             "user_claimed": false,
#                             "voucher_class": 1
#                         },
#                         "count": 6,
#                         "item_list": [
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 20137254458,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 759343791
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 23751256425,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 260118109
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 19682971494,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 4627733
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 22751371383,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 330314777
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 22276845180,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 319151384
#                             },
#                             {
#                                 "ads_info": {
#                                     "ads_type": 0
#                                 },
#                                 "item_id": 19582981087,
#                                 "mcn_campaign_token": "",
#                                 "shop_id": 759343791
#                             }
#                         ],
#                         "items": [
#                             {
#                                 "image": "id-11134207-7r98o-lop566e3h94r76_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98v-lnjr14z88i1ne7_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98x-lnawqiu6it8n8c_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98t-ln8e0hlmklfa72_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r98y-lni8igzkdcnv37_tn"
#                             },
#                             {
#                                 "image": "id-11134207-7r990-lnb0vdeh3wpnaa_tn"
#                             }
#                         ]
#                     },
#                     "qc_labels": [
#                         {
#                             "type": 6
#                         }
#                     ],
#                     "video": {
#                         "cover": "https://down-ws-id.img.susercontent.com/id-11110124-7r98z-lwb90jj2nde917",
#                         "duration": 14934,
#                         "formats": [
#                             {
#                                 "bitrate": 179085,
#                                 "defn": "V360P",
#                                 "duration": 14954,
#                                 "format": 1600408,
#                                 "height": 640,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004081718001498.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004081718001498.mp4",
#                                 "width": 360
#                             },
#                             {
#                                 "bitrate": 325252,
#                                 "defn": "V540P",
#                                 "duration": 14954,
#                                 "format": 1600409,
#                                 "height": 960,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004091718001485.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004091718001485.mp4",
#                                 "width": 540
#                             },
#                             {
#                                 "bitrate": 518595,
#                                 "defn": "V720P",
#                                 "duration": 14954,
#                                 "format": 1600410,
#                                 "height": 1280,
#                                 "path": "api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004101718001498.mp4",
#                                 "profile": "MP4",
#                                 "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004101718001498.mp4",
#                                 "width": 720
#                             }
#                         ],
#                         "height": 1280,
#                         "mms_cover": "https://down-ws-id.img.susercontent.com/id-11110124-7r98z-lwb90jj2nde917",
#                         "mms_data": "{\"biz\":125,\"cover\":\"https://down-ws-id.img.susercontent.com/id-11110124-7r98z-lwb90jj2nde917\",\"create_time\":1717922353,\"default_format\":{\"abitrate\":125419,\"bitrate\":405816,\"defn\":\"V540P\",\"duration\":14954,\"format\":1600323,\"fps\":25.06702,\"height\":960,\"profile\":\"MP4\",\"size\":1004103,\"update_time\":1717922374,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.default.mp4\",\"width\":540},\"duration\":14933,\"extend_formats\":{\"H265\":[{\"abitrate\":96455,\"bitrate\":184707,\"defn\":\"V360P\",\"duration\":14954,\"format\":1600412,\"fps\":25.06702,\"height\":640,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004121718001498.mp4\",\"profile\":\"MP4\",\"size\":541549,\"update_time\":1718001511,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004121718001498.mp4\",\"width\":360},{\"abitrate\":125412,\"bitrate\":248012,\"defn\":\"V540P\",\"duration\":14954,\"format\":1600413,\"fps\":25.06702,\"height\":960,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004131718001498.mp4\",\"profile\":\"MP4\",\"size\":713740,\"update_time\":1718001514,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004131718001498.mp4\",\"width\":540},{\"abitrate\":125412,\"bitrate\":438060,\"defn\":\"V720P\",\"duration\":14954,\"format\":1600414,\"fps\":25.06702,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004141718001498.mp4\",\"profile\":\"MP4\",\"size\":1068182,\"update_time\":1718001525,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004141718001498.mp4\",\"width\":720},{\"abitrate\":125412,\"bitrate\":592905,\"defn\":\"V720P\",\"duration\":14954,\"format\":1600415,\"fps\":25.06702,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004151718001498.mp4\",\"profile\":\"MP4\",\"size\":1356969,\"update_time\":1718001522,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004151718001498.mp4\",\"width\":720}]},\"formats\":[{\"abitrate\":96455,\"bitrate\":179085,\"defn\":\"V360P\",\"duration\":14954,\"format\":1600408,\"fps\":25.06702,\"height\":640,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004081718001498.mp4\",\"profile\":\"MP4\",\"size\":528222,\"update_time\":1718001509,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004081718001498.mp4\",\"width\":360},{\"abitrate\":125412,\"bitrate\":325252,\"defn\":\"V540P\",\"duration\":14954,\"format\":1600409,\"fps\":25.06702,\"height\":960,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004091718001485.mp4\",\"profile\":\"MP4\",\"size\":854950,\"update_time\":1718001497,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004091718001485.mp4\",\"width\":540},{\"abitrate\":125412,\"bitrate\":518595,\"defn\":\"V720P\",\"duration\":14954,\"format\":1600410,\"fps\":25.06702,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004101718001498.mp4\",\"profile\":\"MP4\",\"size\":1215536,\"update_time\":1718001513,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004101718001498.mp4\",\"width\":720},{\"abitrate\":125412,\"bitrate\":802078,\"defn\":\"V720P\",\"duration\":14954,\"format\":1600411,\"fps\":25.06702,\"height\":1280,\"path\":\"api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004111718001498.mp4\",\"profile\":\"MP4\",\"size\":1744231,\"update_time\":1718001513,\"url\":\"https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004111718001498.mp4\",\"width\":720}],\"serviceID\":6,\"update_time\":1717 ...
#                         "preload_mms_data": "",
#                         "preload_url": "",
#                         "size": 22203,
#                         "url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16004101718001498.mp4",
#                         "video_id": "id-11110124-6ke1b-lwb904bmuq7ia8",
#                         "watermark_cover_url": "id-11134114-7r98o-lwb90imvwq9p15",
#                         "watermark_video_url": "https://down-aka-id.vod.susercontent.com/api/v4/11110124/mms/id-11110124-6ke1b-lwb904bmuq7ia8.16003551717922357.3234.mp4",
#                         "width": 720
#                     }
#                 },
#                 "extend": {
#                     "bought": false
#                 },
#                 "in_fmt_wl": false,
#                 "interact": {},
#                 "label": {},
#                 "meta": {
#                     "avatar": "id-11134233-7r98r-lvuch0nixaj172",
#                     "content_type": 0,
#                     "count_info": {
#                         "comments": 248,
#                         "likes": 7182,
#                         "views": 1721111
#                     },
#                     "ctime": 1717922354475,
#                     "human_like": true,
#                     "is_verified": true,
#                     "post_id": "sEcyA1vcBQC8sb0UAAAAAA==",
#                     "qc_info": {
#                         "qc_time": 1719447630181,
#                         "violation_category": 0
#                     },
#                     "qc_status": 1,
#                     "shopee_nick_name": "ona",
#                     "source": 0,
#                     "status": 1,
#                     "user_id": 347976124,
#                     "user_name": "tionaeliaa",
#                     "user_state": 0
#                 },
#                 "recommend_info": {
#                     "algo_info": "RCLG:default,REQID:011719641902894360010211206146026850449,PID:11,EPT:video_trending,TFS:rootsvr_ID,ABTEST:0.z.8888@63961,SEC:video_trending_sec,SECKEY:video_trending_sec,BNDOPT:video_trending,BND:video_trending,RNKG:default,NEW:1,SLT:rootsvr,LOWVVUSER:1,USERGROUP:noage_nogender,USERID:2063807778,DEVICE_FGPT_USERID:2063807778,UIDZERO:1,IS_NEW_USER:0,HISTORYLOWVVUSER:0,COINUSER:0,COREUSER:0,REQTYPE:1,UNIRANK:0,REQCNT:14,VVCNT:20,POS:5,QUE:ShopeeVideo_ecom_weighted_clk,QUES:ShopeeVideo_ecom_weighted_clk|ShopeeVideo_finish_dssm|ShopeeVideo_staytime_dssm_inbatch|ShopeeVideo_ecom_anchor_cvr2,GID:217077825,VIDEOID:1649658337314736,ITEMID:20137254458,SHOPID:759343791,BIND_PRODUCT_SIZE:6,AUTHORID:347976124,SIMID:1649658337314736,RNK:VideoGeneralRanker:{SCORE:13350855267040078074944159744.000000},CORECONTENT:1,TAG_INFO:tag_list:product_related_shuffle,not_video_cold_phase_one,ecom_video1,merchandise_video,core_context,original_author,;tag_map:l1_cate_stats_tag:Beauty & Fashioin,;duration:10_15s,;l1_cat_shuffle:6,;freshness_stats_tag:14_30d,;is_ecom_stats_tag:ecom,;uid_shuffle:347976124,;source_stats_tag:UGC,;first_productid_shuffle:20137254458,;,RRK:original_author_boost_rule=106806842136320624599553277952000.000000&cold_start_ucb_boost_td_v2=106806842136320624599553277952000.000000&new_low_quality_traffic_baiting_deboost_for_td_hpl_ddl=106806842136320624599553277952000.000000&duration_stage_boost=106806842136320624599553277952000.000000",
#                     "ecommerce_source": {
#                         "item_id": 0,
#                         "tag": ""
#                     },
#                     "req_id": "011719641902894360010211206146026850449",
#                     "session_id": "",
#                     "source": 0,
#                     "video_type": 0
#                 },
#                 "relation_source": 0
#             }
#         ],
#         "page": {
#             "has_more": true,
#             "is_newbee": true,
#             "page_context": "[\"eEF8nz69BQCAr1owAAAAAA==\",\"w0dK3dbUBQA5IcYHAAAAAA==\",\"UIePmNetBQDtH7ALAAAAAA==\",\"DUNkUC9eBQBhmGIAAAAAAA==\",\"rgbtKm6vBQB5S5UBAAAAAA==\",\"sEcyA1vcBQC8sb0UAAAAAA==\"]"
#         }
#     }
# }

# %%
# Fungsi untuk memperbaiki harga
def correct_price(price):
    return price // 100000  # Mengurangi 5 angka 0 dari belakang

# Fungsi untuk konversi timestamp
def convert_timestamp(ts):
    return datetime.fromtimestamp(ts / 1000).strftime('%Y-%m-%d %H:%M:%S')

# Fungsi untuk ekstraksi hashtag dari caption
def extract_hashtags(caption):
    return re.findall(r'#\w+', caption)

# %%
data = response.json()

# List untuk menyimpan data utama dan hashtags
main_rows = []
hashtag_rows = []

# Proses data untuk mendapatkan informasi yang dibutuhkan
for item in data['data']['list']:
    post = item['post']
    meta = post['meta']
    content = post['content']
    
    post_id = meta['post_id']
    user_id = meta['user_id']
    user_name = meta['user_name']
    comment_count = meta['count_info']['comments']
    like_count = meta['count_info']['likes']
    view_count = meta['count_info']['views']
    post_date = convert_timestamp(meta['ctime'])
    
    product_name = content['products']['anchor_product']['name']
    offer_link = content['products']['anchor_product']['offer_link']
    product_price = correct_price(content['products']['anchor_product']['price'])
    caption = content.get('caption', '')

    # Tambahkan ke dalam list main_rows
    main_rows.append({
        'Post ID': post_id,
        'User ID': user_id,
        'User Name': user_name,
        'Nama Produk': product_name,
        'Link Penawaran': offer_link,
        'Jumlah Komentar': comment_count,
        'Jumlah Like': like_count,
        'Jumlah View': view_count,
        'Tanggal Post': post_date,
        'Harga Produk': product_price,
        'Caption': caption
    })

    # Proses hashtags dari caption
    hashtags = extract_hashtags(caption)
    for hashtag in hashtags:
        hashtag_id = f"{post_id}_{hashtag}"
        
        hashtag_rows.append({
            'Post ID': post_id,
            'Timestamp': meta['ctime'],
            'Hashtag ID': hashtag_id,
            'Hashtag': hashtag
        })

# Buat DataFrame dari list main_rows
df_main = pd.DataFrame(main_rows)
# Buat DataFrame dari list hashtag_rows
df_hashtags = pd.DataFrame(hashtag_rows)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 9
#       7 # Proses data untuk mendapatkan informasi yang dibutuhkan
#       8 for item in data['data']['list']:
# ----> 9     post = item[0]
#      10     meta = post['meta']
#      11     content = post['content']
#
# KeyError: 0

# %%
data = response.json()
# List untuk menyimpan data utama dan hashtags
main_rows = []
hashtag_rows = []

# Proses data untuk mendapatkan informasi yang dibutuhkan
for post in data['data']['list']:
    meta = post['meta']
    content = post['content']
    
    post_id = meta.get('post_id')
    user_id = meta.get('user_id')
    user_name = meta.get('user_name')
    comment_count = meta['count_info'].get('comments', 0)
    like_count = meta['count_info'].get('likes', 0)
    view_count = meta['count_info'].get('views', 0)
    post_date = convert_timestamp(meta.get('ctime'))
    
    product_name = content['products']['anchor_product'].get('name', '')
    offer_link = content['products']['anchor_product'].get('offer_link', '')
    product_price = correct_price(content['products']['anchor_product'].get('price', 0))
    caption = content.get('caption', '')

    # Tambahkan ke dalam list main_rows
    main_rows.append({
        'Post ID': post_id,
        'User ID': user_id,
        'User Name': user_name,
        'Nama Produk': product_name,
        'Link Penawaran': offer_link,
        'Jumlah Komentar': comment_count,
        'Jumlah Like': like_count,
        'Jumlah View': view_count,
        'Tanggal Post': post_date,
        'Harga Produk': product_price,
        'Caption': caption
    })

    # Proses hashtags dari caption
    hashtags = extract_hashtags(caption)
    for hashtag in hashtags:
        hashtag_id = f"{post_id}_{hashtag}"
        
        hashtag_rows.append({
            'Post ID': post_id,
            'Timestamp': meta.get('ctime'),
            'Hashtag ID': hashtag_id,
            'Hashtag': hashtag
        })

# Buat DataFrame dari list main_rows
df_main = pd.DataFrame(main_rows)
# Buat DataFrame dari list hashtag_rows
df_hashtags = pd.DataFrame(hashtag_rows)

# Tampilkan hasil
print(len(df_main))
df_main.head()
# Out:
# 6
#                     Post ID    User ID        User Name  \
# 0  eEF8nz69BQCAr1owAAAAAA==  811249536     amelnhasanah
# 1  w0dK3dbUBQA5IcYHAAAAAA==  130425145     namakuindri_
# 2  UIePmNetBQDtH7ALAAAAAA==  196091885       balaboo.id
# 3  DUNkUC9eBQBhmGIAAAAAAA==    6461537          lutviar
# 4  rgbtKm6vBQB5S5UBAAAAAA==   26561401  seokjinkhan92nm
#
#                                          Nama Produk  \
# 0  Isi binder A6 saving challenge Tebal 260 gsm (...
# 1  Latiao Family Snack - [HALAL] WLM Gluten Latia...
# 2  Satu Keluarga Mainan Anak Kolam Renang Karet M...
# 3  JM - [BPOM] Parfum Inspired Le Labo 35ml / Par...
# 4  i16 Pro Hp Flip F15 Mini Flip Phone Jadul Ori ...
#
#                     Link Penawaran  Jumlah Komentar  Jumlah Like  Jumlah View  \
# 0      https://shope.ee/7UuUec27XR               13          652       112560
# 1  https://s.shopee.co.id/owx9XCTk               90         4772      1031330
# 2       https://shope.ee/B7aq40wzY              571         8953      3318774
# 3      https://shope.ee/4KvZ6Kjas6              589        14760      4160968
# 4      https://shope.ee/7pX3w8nv0q               78         4190      1110433
#
#           Tanggal Post  Harga Produk  \
# 0  2024-05-16 11:42:17           999
# 1  2024-06-03 19:32:30         10900
# 2  2024-05-04 12:34:56         82037
# 3  2024-03-03 15:39:42          6288
# 4  2024-05-05 18:11:16        290000
#
#                                              Caption
# 0  Binder keuangan #spillracunshopee #shopeehaul ...
# 1  Latiao snack #latiao #latiaoviral #fyp #RacunS...
# 2  Kolam renang portable #kolamrenangportable #Di...
# 3  viral murah,tahan lama🥹 #RacunShopee #ViralDiS...
# 4  hp lipat jadul mirip iphone #RacunShopeeCheck ...

# %%
# Tentukan nama file CSV
main_file_name = 'scraped_sv_product_data.csv'
hashtag_file_name = 'scraped_sv_hashtags.csv'

# Simpan DataFrame utama ke file CSV
if os.path.isfile(main_file_name):
    df_main.to_csv(main_file_name, mode='a', header=False, index=False)
else:
    df_main.to_csv(main_file_name, mode='w', header=True, index=False)

# Simpan DataFrame hashtags ke file CSV
if os.path.isfile(hashtag_file_name):
    df_hashtags.to_csv(hashtag_file_name, mode='a', header=False, index=False)
else:
    df_hashtags.to_csv(hashtag_file_name, mode='w', header=True, index=False)

# Tampilkan panjang data (jumlah baris) yang baru saja di-scrap
print("Panjang data yang baru di-scrap:", len(df_main))
print("Panjang data hashtags yang baru di-scrap:", len(df_hashtags))

# Tampilkan DataFrame yang baru di-scrap
# print(df_main)
# print(df_hashtags)
# Out:
# Panjang data yang baru di-scrap: 6
# Panjang data hashtags yang baru di-scrap: 39

# %%
print("Panjang data yang baru di-scrap:", len(df_main))
print("Panjang data hashtags yang baru di-scrap:", len(df_hashtags))

df_main
# Out:
# Panjang data yang baru di-scrap: 6
# Panjang data hashtags yang baru di-scrap: 39
#                     Post ID     User ID          User Name  \
# 0  pcGZ0BGSBQAqCjImAAAAAA==   640813610    kiya.official08
# 1  k0fnXKRBBQARGpgAAAAAAA==     9968145            azfiroh
# 2  vEYVQfq1BQC4UAMAAAAAAA==      217272        shirlyrezky
# 3  V0H1xTChBQCxDTpIAAAAAA==  1211764145  mariaelvalintania
# 4  PQdvEVHCBQBDHnkCAAAAAA==    41492035         selafianaa
# 5  zoBV1o9wBQDDBms8AAAAAA==  1013647043         spillhouse
#
#                                          Nama Produk  \
# 0  Jam Tangan SHSHD RANTAI - Jam Tangan Strap Sta...
# 1      [ACQ] Alat Pel Mini Lipat Alat Pembersih Kaca
# 2  [Pre-Order] ELFORMULA Intensive Peeling Soluti...
# 3  MTE Timbangan Badan Kaca Digital Body Elektron...
# 4                   Facetology Triple Care Sunscreen
# 5  Deboss-Y08 HEADPHONE BLUETOOTH HEADSET WIRELES...
#
#                 Link Penawaran  Jumlah Komentar  Jumlah Like  Jumlah View  \
# 0  https://shope.ee/4KwbOUYLZc                7          140        50060
# 1  https://shope.ee/8zgpJNNaUS              517         5848       991421
# 2  https://shope.ee/AUXxDwALaQ              152          852        81858
# 3   https://shope.ee/LQlGvDmmF              119          332        62998
# 4  https://shope.ee/9pIViUL7pL              129         3014       561187
# 5  https://shope.ee/6Kh0GPuAdc              308        12470      2232296
#
#           Tanggal Post  Harga Produk  \
# 0  2024-04-12 22:51:50         12900
# 1  2024-02-10 11:35:08         10969
# 2  2024-05-10 20:14:13        128000
# 3  2024-04-24 16:44:18         37999
# 4  2024-05-20 10:15:17         69900
# 5  2024-03-17 22:14:04         32500
#
#                                              Caption
# 0  jam tangan rantai murah #RacunShopee #ShopeeCO...
# 1  Alat pel otomatis #cashbackshopeevideo #RacunS...
# 2  Bikin kinclong muka bun #shopeevideofeed #Shop...
# 3  Masukin keranjang dulu biar ga lupa😍 #RacunSho...
# 4  wajib pake sunscreen ya #sunscreen #sunscreenv...
# 5  #RamadanKembaliKuat #headphonebluetooth #headp...
