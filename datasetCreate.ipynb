# %%
import csv

gadget_keywords = [
    "Smartphone", "Tablet", "Laptop", "Smartwatch", "Fitness Tracker", "Bluetooth Earbuds", "Wireless Headphones", 
    "Portable Speaker", "Gaming Console", "VR Headset", "Action Camera", "Drone", "Smart Home Hub", "Smart Light Bulb", 
    "Smart Plug", "Smart Thermostat", "Security Camera", "E-Reader", "Portable Charger", "Power Bank", "USB-C Hub", 
    "External Hard Drive", "SSD", "Memory Card", "Flash Drive", "Router", "Mesh Wi-Fi System", "Network Switch", 
    "Bluetooth Adapter", "Graphics Tablet", "Drawing Tablet", "Digital Pen", "Mechanical Keyboard", "Gaming Mouse", 
    "Webcam", "Microphone", "Ring Light", "Streaming Kit", "Smart Glasses", "Fitness Band", "Smart Scale", 
    "Blood Pressure Monitor", "Pulse Oximeter", "Smart Lock", "Smart Doorbell", "Robot Vacuum", "3D Printer", 
    "VR Controllers", "Portable Monitor", "Laptop Stand", "Ergonomic Chair", "Desk Lamp", "Monitor Arm", "Cable Organizer", 
    "Wireless Charger", "Phone Case", "Screen Protector", "Laptop Sleeve", "Backpack", "Car Charger", "Bluetooth Tracker", 
    "Smart Key Finder", "Selfie Stick", "Gimbal", "Tripod", "Camera Lens", "Lens Filter", "Memory Card Reader", 
    "Smart Pen", "Digital Voice Recorder", "Projector", "Portable Projector", "Streaming Device", "TV Box", "Smart TV", 
    "4K TV", "8K TV", "Soundbar", "Home Theater System", "Bluetooth Speaker", "Multi-Room Audio System", 
    "Portable Bluetooth Speaker", "Noise Cancelling Headphones", "Smart Alarm Clock", "Fitness Tracker with GPS", 
    "Heart Rate Monitor", "Wireless Earbuds", "Over-Ear Headphones", "In-Ear Headphones", "Gaming Headset", 
    "Soundproof Headphones", "Portable Bluetooth Keyboard", "Bluetooth Mouse", "Stylus Pen", "Smart Ring", "Smart Bracelet", 
    "Smart Jewelry", "Smart Clothes", "VR Backpack", "Augmented Reality Glasses", "Smart Bike", "Electric Scooter", 
    "Electric Skateboard", "Hoverboard", "Portable Solar Charger", "Smart Water Bottle", "Smart Mug", "Smart Fridge", 
    "Smart Oven", "Smart Microwave", "Smart Washing Machine", "Smart Air Purifier", "Smart Fan", "Smart Heater", 
    "Smart Air Conditioner", "Smart Dehumidifier", "Smart Bed", "Smart Pillow", "Sleep Tracker", "Portable AC", 
    "Wearable Camera", "Body Camera", "Dash Cam", "Pet Tracker", "Smart Collar", "Robot Dog", "Robot Cat", 
    "Pet Camera", "Smart Litter Box", "Automatic Feeder", "Smart Pet Door", "Smart Bird Feeder", "Smart Plant Pot", 
    "Smart Sprinkler", "Smart Irrigation System", "Weather Station", "Portable Generator", "Portable Air Pump", 
    "Electric Kettle", "Smart Coffee Maker", "Smart Blender", "Smart Toaster", "Smart Scale", "Smart Oven Mitts", 
    "Smart Thermometer", "Smart Measuring Cup", "Smart Faucet", "Smart Shower Head", "Smart Toothbrush", 
    "Smart Mirror", "Smart Weighing Scale", "Smart Skipping Rope", "Smart Yoga Mat", "Smart Jump Rope", 
    "Smart Mat", "Smart Speaker with Screen", "Smart Speaker with Camera", "Smart Doorbell with Camera", 
    "Smart Security System", "Smart Alarm System", "Smart Intercom", "Smart Baby Monitor", "Smart Video Baby Monitor", 
    "Smart Pet Monitor", "Smart Leak Detector", "Smart Smoke Detector", "Smart Carbon Monoxide Detector", 
    "Smart Thermostat with Voice Control", "Smart Light Switch", "Smart Dimmer Switch", "Smart Light Strip", 
    "Smart Ceiling Fan", "Smart Blinds", "Smart Curtains", "Smart Window Shades", "Smart Air Purifier with HEPA Filter", 
    "Smart Humidifier", "Smart Dehumidifier with Wi-Fi", "Smart Fan with Wi-Fi", "Smart Heater with Wi-Fi", 
    "Smart AC with Wi-Fi", "Smart Oven with Wi-Fi", "Smart Refrigerator with Wi-Fi", "Smart Washing Machine with Wi-Fi", 
    "Smart Dryer with Wi-Fi", "Smart Dishwasher with Wi-Fi", "Smart Vacuum Cleaner with Wi-Fi", "Smart Mop with Wi-Fi", 
    "Smart Air Fryer", "Smart Pressure Cooker", "Smart Multicooker", "Smart Rice Cooker", "Smart Slow Cooker", 
    "Smart Bread Maker", "Smart Toaster Oven", "Smart Ice Maker", "Smart Meat Thermometer", "Smart Meat Probe", 
    "Smart BBQ Grill", "Smart BBQ Smoker", "Smart Sous Vide Cooker", "Smart Wine Cooler", "Smart Wine Decanter", 
    "Smart Wine Opener", "Smart Coffee Grinder", "Smart Espresso Machine", "Smart Milk Frother", "Smart Tea Maker", 
    "Smart Tea Kettle", "Smart Water Filter", "Smart Water Pitcher", "Smart Water Dispenser", "Smart Soda Maker", 
    "Smart Yogurt Maker", "Smart Ice Cream Maker", "Smart Vacuum Sealer", "Smart Blender Bottle", "Smart Cocktail Maker", 
    "Smart Citrus Juicer", "Smart Juicer", "Smart Food Processor", "Smart Food Chopper", "Smart Food Dehydrator", 
    "Smart Food Steamer", "Smart Microwave Oven", "Smart Toaster with Camera", "Smart Refrigerator with Camera", 
    "Smart Oven with Camera", "Smart Washing Machine with Camera", "Smart Dishwasher with Camera", "Smart Vacuum Cleaner with Camera", 
    "Smart AC with Camera", "Smart Heater with Camera", "Smart Fan with Camera", "Smart Humidifier with Camera", 
    "Smart Air Purifier with Camera", "Smart Light Bulb with Camera", "Smart Plug with Camera", "Smart Thermostat with Camera", 
    "Smart Switch with Camera", "Smart Dimmer Switch with Camera", "Smart Light Strip with Camera", "Smart Blinds with Camera", 
    "Smart Curtains with Camera", "Smart Window Shades with Camera", "Smart Mattress", "Smart Bed Frame", "Smart Pillow with Sensor", 
    "Smart Bed with Wi-Fi", "Smart Bed with Bluetooth", "Smart Bed with Speaker", "Smart Bed with Light", "Smart Bed with USB Port", 
    "Smart Bed with Phone Charger", "Smart Bed with Tablet Holder", "Smart Bed with Massage", "Smart Bed with Cooling", 
    "Smart Bed with Heating", "Smart Bed with Vibration", "Smart Bed with Alarm", "Smart Bed with Voice Control", 
    "Smart Bed with Sleep Tracker", "Smart Bed with Heart Rate Monitor", "Smart Bed with Blood Pressure Monitor", 
    "Smart Bed with Oximeter", "Smart Bed with ECG", "Smart Bed with EMG", "Smart Bed with EEG", "Smart Bed with Camera", 
    "Smart Bed with Microphone", "Smart Bed with Speaker", "Smart Bed with Screen", "Smart Bed with Wi-Fi", 
    "Smart Bed with Bluetooth", "Smart Bed with Light", "Smart Bed with USB Port", "Smart Bed with Phone Charger", 
    "Smart Bed with Tablet Holder", "Smart Bed with Massage", "Smart Bed with Cooling", "Smart Bed with Heating", 
    "Smart Bed with Vibration", "Smart Bed with Alarm", "Smart Bed with Voice Control", "Smart Bed with Sleep Tracker", 
    "Smart Bed with Heart Rate Monitor", "Smart Bed with Blood Pressure Monitor", "Smart Bed with Oximeter", 
    "Smart Bed with ECG", "Smart Bed with EMG", "Smart Bed with EEG", "Smart Bed with Camera", "Smart Bed with Microphone", 
    "Smart Bed with Speaker", "Smart Bed with Screen","TWS","Fancooler","WIFI","Elektrik","Elektronik","Lampu","Smart","Led","Monitor",
    "Light","Senter","Tenaga Surya","Kabel","Solar"
]

# Menyimpan ke file CSV
with open('brand_and_gadget_keywords.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Brand"])
    for keyword in gadget_keywords:
        writer.writerow([keyword])

# %%
brand_keywords = [
    "Apple", "Samsung", "Sony", "LG", "Microsoft", "Google", "Amazon", "Huawei", "Xiaomi", "OnePlus", "Nokia", 
    "Lenovo", "Asus", "Acer", "HP", "Dell", "Intel", "AMD", "NVIDIA", "Qualcomm", "Razer", "Logitech", "Corsair", 
    "Anker", "JBL", "Bose", "Sennheiser", "Beats", "Bang & Olufsen", "Garmin", "Fitbit", "Oppo", "Vivo", "Realme", 
    "Poco", "Honor", "ZTE", "Motorola", "Panasonic", "Philips", "Toshiba", "Sharp", "Casio", "Canon", "Nikon", 
    "Fujifilm", "Olympus", "GoPro", "DJI", "Ring", "Eufy", "Wyze", "Arlo", "Netgear", "TP-Link", "Linksys", 
    "Ubiquiti", "Synology", "QNAP", "Western Digital", "Seagate", "Sandisk", "Kingston", "Crucial", "HyperX", 
    "ADATA", "Samsung SSD", "Intel SSD", "WD SSD", "Seagate SSD", "Logitech G", "Razer Blade", "Alienware", 
    "MSI", "Gigabyte", "EVGA", "ASRock", "Zotac", "Cooler Master", "NZXT", "Thermaltake", "Lian Li", "Corsair Gaming", 
    "SteelSeries", "Mad Catz", "Astro Gaming", "HyperX Gaming", "Turtle Beach", "Plantronics", "Blue Microphones", 
    "Elgato", "Aukey", "Belkin", "Mophie", "OtterBox", "Spigen", "Anker Power", "Anker Innovations", "Belkin International", 
    "Griffin Technology", "Satechi", "Ring Video Doorbell", "Wyze Cam", "Arlo Pro", "Nest Hello", "August Smart Lock", 
    "Schlage Encode", "Eero", "Google Nest", "TP-Link Deco", "Netgear Orbi", "Linksys Velop", "Amazon Echo", 
    "Google Nest Hub", "Apple HomePod", "Sonos", "Bose SoundLink", "JBL Charge", "UE Boom", "Marshall", "Yamaha", 
    "Harman Kardon", "Sony WH-1000XM4", "Bose QuietComfort", "Sennheiser Momentum", "Apple AirPods", "Samsung Galaxy Buds", 
    "Jabra Elite", "Anker Soundcore", "Beats by Dre", "Sony WF-1000XM3", "Google Pixel Buds", "Microsoft Surface", 
    "Apple MacBook", "Dell XPS", "HP Spectre", "Lenovo ThinkPad", "Asus ZenBook", "Acer Predator", "MSI Stealth", 
    "Razer Blade", "Samsung Galaxy Tab", "Apple iPad", "Microsoft Surface Pro", "Amazon Fire", "Huawei MatePad", 
    "Lenovo Yoga", "Asus ROG", "Acer Nitro", "Sony PlayStation", "Microsoft Xbox", "Nintendo Switch", "Valve Index", 
    "Oculus Rift", "HTC Vive", "Google Cardboard", "HP Reverb", "Canon EOS", "Nikon D", "Sony Alpha", "Fujifilm X", 
    "Olympus OM-D", "GoPro Hero", "DJI Mavic", "Parrot Anafi", "Skydio", "Autel Robotics", "Holy Stone", "Ryze Tello", 
    "3D Systems", "Formlabs", "Creality", "Anycubic", "Prusa Research", "Flashforge", "Ultimaker", "Raise3D", 
    "Geeetech", "QIDI Tech", "Artillery", "Voxelab", "Snapmaker"
]

# Menyimpan ke file CSV
with open('brand_and_gadget_keywords.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Brand"])
    for brand in brand_keywords:
        writer.writerow([brand])
